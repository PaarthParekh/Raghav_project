# %%
# Import modules

# %matplotlib notebook

#import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt
from obspy import UTCDateTime, read, read_inventory, read_events
from obspy.clients.fdsn import Client
from obspy.clients.fdsn.header import FDSNNoDataException
from datetime import datetime, timedelta, timezone

import pandas as pd
from scipy.interpolate import interp1d
import os
import shutil

from time import time
import pickle

# %%
# Define the data directories

cwd = os.getcwd()
data_dir = os.path.join(cwd, "data")
raw_waveform_dir = os.path.join(data_dir, "waveforms_raw")
processed_waveform_dir = os.path.join(data_dir, "waveforms_proc_broadband")

# %%
# Remove the old directories and create new ones

if os.path.isdir(raw_waveform_dir):
    shutil.rmtree(raw_waveform_dir)
os.mkdir(raw_waveform_dir)

if os.path.isdir(processed_waveform_dir):
    shutil.rmtree(processed_waveform_dir)
os.mkdir(processed_waveform_dir)

# %% [markdown]
# # Station inventory and event catalogue

# %% [markdown]
# First, we define the parameters for the data acquisition. We take the catalogue from the Southern California Seismic Network (`CI`) from 2000 to 2015, and select all seismic stations and events recorded within a latitude range of 32$^{\circ}$ to 36$^{\circ}$, and within a longitude range of -120$^{\circ}$ to -116$^{\circ}$.

# %%
# Parameters

client = Client("IRIS")
network = "CI"  # Southern California Seismic Network

inventory_filename = "inventory.xml"
catalogue_filename = "catalogue.file"

starttime = UTCDateTime("2000-01-01T00:00:00")
endtime = UTCDateTime("2015-01-01T00:00:00")

station_settings = {
    "network": "CI",
    "minlatitude": 32,
    "maxlatitude": 36,
    "minlongitude": -120,
    "maxlongitude": -116,
    "startbefore": endtime,
    "endafter": starttime,
    "level": "response",
    "filename": inventory_filename,
    "format": "xml",
    "channel": "BHN,BHE,BHZ",
}

event_settings = {
    "minlatitude": 32,
    "maxlatitude": 36,
    "minlongitude": -120,
    "maxlongitude": -116,
    "starttime": starttime,
    "endtime": endtime,
    "minmagnitude": 3.0,
    "filename": catalogue_filename,
}

# %%
# Get seismic stations (may take a few minutes)

client.get_stations(**station_settings)

# %% [markdown]
# We create a Pandas dataframe with some useful station metadata:

# %%
# Read the stations
stations = read_inventory(inventory_filename).select(network=network)[0]
# Get the station codes (sort alphabetically)
station_codes = np.sort([station.code for station in stations])
# Define the dataframe
station_df = pd.DataFrame(columns=("code", "lat", "lon", "start_date", "end_date"))

# Loop over sorted station codes
for station_code in station_codes:
    # Select the station data
    station = stations.select(station=station_code)[0]
    # Append station metadata to dataframe
    station_df = station_df.append(
        {
            "code": station_code, 
            "lat": station.latitude, 
            "lon": station.longitude,
            "start_date": station.start_date,
            "end_date": station.end_date,
        }, ignore_index=True
    )

# Save dataframe to CSV
station_df.to_csv(os.path.join(data_dir, "stations.csv"), index=False)

# %% [markdown]
# As a quick sanity check, we plot the station locations:

# %%
# Print out number of stations
print(len(station_df))
# Plot station locations
pl = stations.plot(projection="local", resolution="i", show=True)
plt.show()
# Out:
# 187
# <img src="data:image/png;base64,..." width="200">

# %% [markdown]
# Next, we download the SCSN event catalogue:

# %%
client.get_events(**event_settings)

# %%
# Read events from file
catalogue = read_events(catalogue_filename)
print(catalogue)
# Out:
# 1386 Event(s) in Catalog:
# 2014-12-31T06:27:41.700000Z | +34.630, -118.623 | 3.1 ML
# 2014-12-30T23:26:17.810000Z | +33.576, -118.276 | 4.0 ML
# ...
# 2000-01-02T17:58:32.230000Z | +34.309, -116.081 | 3.2 ML
# 2000-01-01T03:58:38.570000Z | +34.835, -116.288 | 3.1 ML
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %% [markdown]
# Again, we plot some events just to check everything went as expected:

# %%
catalogue.plot(projection="local", resolution="i", show=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="200">
# /home/lchuang/anaconda/envs/eqt/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/lchuang/anaconda/envs/eqt/lib/python3.7/site-packages/obspy/imaging/maps.py:305: MatplotlibDeprecationWarning: The 'cmap' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   ticks=locator, format=formatter, **cb_kwargs)

# %% [markdown]
# # Downloading the raw waveforms

# %% [markdown]
# In the cell below, we download the waveforms and create a lookup table for the stations that were operational at the time of the event. While looping over all events in the catalogue, we select the "preferred" origin time, location, and magnitude, and check which stations were operational around the origin time. We then download the three-component waveforms up to 120 seconds after the origin time for each operational station.
#
# **Note 1**: the "operational" stations have not necessarily recorded anything. We will do additional quality checking in a subsequent step.
#
# **Note 2**: downloading the waveforms takes several hours with a fast internet connection.

# %%
# Initiate event catalogue dataframe
catalogue_df = pd.DataFrame(columns=("time", "lat", "lon", "depth", "mag"))
# Initiate station lookup table
catalogue_station_lookup = {}

t0 = time()
ETA = 0

# Loop over events in SCSN catalogue
for i, event in enumerate(catalogue):
    
    # Calculate ETA based on average processing time
    running_time = time() - t0
    events_per_sec = (i + 1) / running_time
    events_to_do = len(catalogue) - i
    ETA = events_to_do / events_per_sec
    
    print("Fetching event %d / %d [ETA: %.d s]" % (i+1, len(catalogue), ETA))
    
    # Check which event origin time/location and magnitude are preferred
    pref_origin = event.preferred_origin_id
    pref_magnitude = event.preferred_magnitude_id
    origins = event.origins
    magnitudes = event.magnitudes
    
    # Grab preferred origin
    for origin in origins:
        if origin.resource_id == pref_origin:
            break
    
    # Grab preferred magnitude
    for magnitude in magnitudes:
        if magnitude.resource_id == pref_magnitude:
            break
    
    # Append event to dataframe
    catalogue_df = catalogue_df.append(
        {"time": origin.time, "lat": origin.latitude, "lon": origin.longitude, "depth": origin.depth, "mag": magnitude.mag}, 
        ignore_index=True
    )
    
    # Waveform output file
    waveform_file = os.path.join(raw_waveform_dir, "%d.sac" % i)
    
    # Start and end time of waveforms
    start_trace = origin.time
    end_trace = origin.time + timedelta(seconds=120)
    
    # Check which stations were operational
    # Station commissioned before start time
    station_inds = (station_df["start_date"] < start_trace)
    # (and) station decommissioned after end time, or still operational
    station_inds = station_inds & ((station_df["end_date"] > end_trace) | station_df["end_date"].isnull())
    # Get station codes of operational stations
    operational_stations = np.sort(station_df["code"][station_inds].values)
    # Append operational stations to lookup table
    catalogue_station_lookup[i] = operational_stations
    
    # Generate query for requesting waveforms
    bulk_query = [(network, station, "*", "BH*", start_trace, end_trace) for station in operational_stations]
    
    print("Fetching data for %d stations" % len(operational_stations))
    
    # Get the data (if available) and write to output file
    try:
        client.get_waveforms_bulk(bulk_query, filename=waveform_file)
    # If FDSN complains: move on
    except FDSNNoDataException:
        print("No data...")
        continue

# Write event catalogue to CSV
catalogue_df.to_csv(os.path.join(data_dir, "catalogue.csv"))

# Write lookup table to binary object
lookup_file = os.path.join(data_dir, "catalogue_station_lookup.pickle")
with open(lookup_file, "wb") as f:
    pickle.dump(catalogue_station_lookup, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Processing the waveforms

# %% [markdown]
# After downloading the raw waveforms, we pre-process them to serve as an input to the deep learning model. First we check for each station that its response is available. Then we filter the waveforms between 0.1 and 8 Hz and interpolate the data onto a common time base sampled at ~20 Hz.
#
# **Note**: this again takes several hours

# %%
from obspy.core.util.obspy_types import ObsPyException

# Read in the event catalogue
catalogue_df = pd.read_csv(os.path.join(data_dir, "catalogue.csv"))
# Convert time to timestamp
catalogue_df["time"] = pd.to_datetime(catalogue_df["time"])

Ntrace = 3     # Number of waveform components
Nt = 2048      # Number of time elements
scale = 1e5    # Scaling factor for waveform amplitude

t0_ETA = time()
ETA = 0

# Buffer to event-station lookup table
catalogue_station_lookup_final = {}

# Loop over all events in the catalogue
for i, event in catalogue_df.iterrows():
    
    # Calculate ETA based on average processing time
    running_time = time() - t0_ETA
    events_per_sec = (i + 1) / running_time
    events_to_do = len(catalogue) - i
    ETA = events_to_do / events_per_sec
    
    print("Processing event %d / %d [ETA: %d s]" % (i+1, len(catalogue), ETA))
    
    # Define the raw waveform file
    event_file = os.path.join(raw_waveform_dir, "%d.sac" % i)
    # If the data file does not exist (due to FDSN error in previous step): skip
    if not os.path.isfile(event_file):
        print("Event %d not found" % (i + 1))
        continue
    
    # Select all operational stations
    operational_stations = catalogue_station_lookup[i]
    # Number of operational stations
    Nstations = len(operational_stations)
    
    # Read the waveforms from file
    data = read(event_file)
    
    # Create a common time base from 1 < t < 101 seconds after the origin time
    starttime = event["time"] + timedelta(seconds=1)
    endtime = starttime + timedelta(seconds=101)
    time_base = pd.date_range(starttime, endtime, periods=Nt).to_pydatetime()
    # Create time base to proper UTC time (including DST and such)
    timestamp_base = np.array([dt.replace(tzinfo=timezone.utc).timestamp() for dt in time_base])
    # Make time base relative to start time
    t0 = timestamp_base.min()
    t_int = timestamp_base - t0
    
    # Buffer for processed waveforms (default to NaN for later pruning)
    proc_data = np.zeros((Nstations, Nt, 3)) * np.nan
    
    # Loop over operational stations
    for k, station in enumerate(operational_stations):
        # Select data stream for current station
        stream = data.select(station=station)
        # Check if all 3 components are present (no more, no less)
        if len(stream) == Ntrace:
            # Subtract mean of the trace
            stream.detrend("simple") 
            # Check if we can remove the station response (doesn't always work)
            try:
                stream.remove_response(inventory=stations, zero_mean=True)
            # Sometimes the station response information is not available
            except ValueError:
                print("Response could not be removed")
                continue
            # Sometimes ObsPy throws a weird error
            except ObsPyException as e:
                print("Weird Obspy exception")
                continue
            # If everything went well, filter signals between 0.1 and 8 Hz
            stream.filter("bandpass", freqmin=0.1, freqmax=8.0, zerophase=True)
            # Loop over waveform components
            for n in range(Ntrace):
                # Extract component
                trace = stream[n]
                tr_data = trace.data
                # Subtract mean (just in case)
                tr_data -= tr_data.mean()
                # Multiply with arbitrary scale
                tr_data *= scale
                # Component time base
                t = trace.times(type="timestamp") - t0
                # Interpolate data onto common time base and store in buffer
                proc_data[k, :, n] = interp1d(t, tr_data, fill_value=0, bounds_error=False, assume_sorted=True)(t_int)
    
    # Check which stations have valid data (i.e. which rows in proc_data are not NaN)
    ok_inds = np.isfinite(proc_data[:, 0, 0])
    # Append the stations that have valid data to lookup table
    catalogue_station_lookup_final[i] = operational_stations[ok_inds]
    # Define processed waveform output file
    proc_data_file = os.path.join(processed_waveform_dir, "%d.npy" % i)
    # Write output file
    np.save(proc_data_file, proc_data[ok_inds])

# Write lookup table to disk
lookup_file = os.path.join(data_dir, "catalogue_station_lookup_final.pickle")
with open(lookup_file, "wb") as f:
    pickle.dump(catalogue_station_lookup_final, f, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Processing event 1 / 1386 [ETA: 3 s]
# Event 1 not found
# Processing event 2 / 1386 [ETA: 2 s]
# Event 2 not found
# Processing event 3 / 1386 [ETA: 2 s]
# Event 3 not found
# Processing event 4 / 1386 [ETA: 1 s]
# Event 4 not found
# Processing event 5 / 1386 [ETA: 1 s]
# Event 5 not found
# Processing event 6 / 1386 [ETA: 1 s]
# Event 6 not found
# Processing event 7 / 1386 [ETA: 1 s]
# Event 7 not found
# Processing event 8 / 1386 [ETA: 1 s]
# Event 8 not found
# Processing event 9 / 1386 [ETA: 1 s]
# Event 9 not found
# Processing event 10 / 1386 [ETA: 1 s]
# Event 10 not found
# Processing event 11 / 1386 [ETA: 1 s]
# Event 11 not found
# Processing event 12 / 1386 [ETA: 1 s]
# Event 12 not found
# Processing event 13 / 1386 [ETA: 1 s]
# Event 13 not found
# Processing event 14 / 1386 [ETA: 1 s]
# Event 14 not found
# Processing event 15 / 1386 [ETA: 1 s]
# Event 15 not found
# Processing event 16 / 1386 [ETA: 0 s]
# Event 16 not found
# Processing event 17 / 1386 [ETA: 0 s]
# Event 17 not found
# Processing event 18 / 1386 [ETA: 0 s]
# Event 18 not found
# Processing event 19 / 1386 [ETA: 0 s]
# Event 19 not found
# Processing event 20 / 1386 [ETA: 0 s]
# Event 20 not found
# Processing event 21 / 1386 [ETA: 0 s]
# Event 21 not found
# Processing event 22 / 1386 [ETA: 0 s]
# Event 22 not found
# Processing event 23 / 1386 [ETA: 0 s]
# Event 23 not found
# Processing event 24 / 1386 [ETA: 0 s]
# Event 24 not found
# Processing event 25 / 1386 [ETA: 0 s]
# Event 25 not found
# Processing event 26 / 1386 [ETA: 0 s]
# Event 26 not found
# Processing event 27 / 1386 [ETA: 0 s]
# Event 27 not found
# Processing event 28 / 1386 [ETA: 0 s]
# Event 28 not found
# Processing event 29 / 1386 [ETA: 0 s]
# Event 29 not found
# Processing event 30 / 1386 [ETA: 0 s]
# Event 30 not found
# Processing event 31 / 1386 [ETA: 0 s]
# Event 31 not found
# Processing event 32 / 1386 [ETA: 0 s]
# Event 32 not found
# Processing event 33 / 1386 [ETA: 0 s]
# Event 33 not found
# Processing event 34 / 1386 [ETA: 0 s]
# Event 34 not found
# Processing event 35 / 1386 [ETA: 0 s]
# Event 35 not found
# Processing event 36 / 1386 [ETA: 0 s]
# Event 36 not found
# Processing event 37 / 1386 [ETA: 0 s]
# Event 37 not found
# Processing event 38 / 1386 [ETA: 0 s]
# Event 38 not found
# Processing event 39 / 1386 [ETA: 0 s]
# Event 39 not found
# Processing event 40 / 1386 [ETA: 0 s]
# Event 40 not found
# Processing event 41 / 1386 [ETA: 0 s]
# Event 41 not found
# Processing event 42 / 1386 [ETA: 0 s]
# Event 42 not found
# Processing event 43 / 1386 [ETA: 0 s]
# Event 43 not found
# Processing event 44 / 1386 [ETA: 0 s]
# Event 44 not found
# Processing event 45 / 1386 [ETA: 0 s]
# Event 45 not found
# Processing event 46 / 1386 [ETA: 0 s]
# Event 46 not found
# Processing event 47 / 1386 [ETA: 0 s]
# Event 47 not found
# Processing event 48 / 1386 [ETA: 0 s]
# Event 48 not found
# Processing event 49 / 1386 [ETA: 0 s]
# Event 49 not found
# Processing event 50 / 1386 [ETA: 0 s]
# Event 50 not found
# Processing event 51 / 1386 [ETA: 0 s]
# Event 51 not found
# Processing event 52 / 1386 [ETA: 0 s]
# Event 52 not found
# Processing event 53 / 1386 [ETA: 0 s]
# Event 53 not found
# Processing event 54 / 1386 [ETA: 0 s]
# Event 54 not found
# Processing event 55 / 1386 [ETA: 0 s]
# Event 55 not found
# Processing event 56 / 1386 [ETA: 0 s]
# Event 56 not found
# Processing event 57 / 1386 [ETA: 0 s]
# Event 57 not found
# Processing event 58 / 1386 [ETA: 0 s]
# Event 58 not found
# Processing event 59 / 1386 [ETA: 0 s]
# Event 59 not found
# Processing event 60 / 1386 [ETA: 0 s]
# Event 60 not found
# Processing event 61 / 1386 [ETA: 0 s]
# Event 61 not found
# Processing event 62 / 1386 [ETA: 0 s]
# Event 62 not found
# Processing event 63 / 1386 [ETA: 0 s]
# Event 63 not found
# Processing event 64 / 1386 [ETA: 0 s]
# Event 64 not found
# Processing event 65 / 1386 [ETA: 0 s]
# Event 65 not found
# Processing event 66 / 1386 [ETA: 0 s]
# Event 66 not found
# Processing event 67 / 1386 [ETA: 0 s]
# Event 67 not found
# Processing event 68 / 1386 [ETA: 0 s]
# Event 68 not found
# Processing event 69 / 1386 [ETA: 0 s]
# Event 69 not found
# Processing event 70 / 1386 [ETA: 0 s]
# Event 70 not found
# Processing event 71 / 1386 [ETA: 0 s]
# Event 71 not found
# Processing event 72 / 1386 [ETA: 0 s]
# Event 72 not found
# Processing event 73 / 1386 [ETA: 0 s]
# Event 73 not found
# Processing event 74 / 1386 [ETA: 0 s]
# Event 74 not found
# Processing event 75 / 1386 [ETA: 0 s]
# Event 75 not found
# Processing event 76 / 1386 [ETA: 0 s]
# Event 76 not found
# Processing event 77 / 1386 [ETA: 0 s]
# Event 77 not found
# Processing event 78 / 1386 [ETA: 0 s]
# Event 78 not found
# Processing event 79 / 1386 [ETA: 0 s]
# Event 79 not found
# Processing event 80 / 1386 [ETA: 0 s]
# Event 80 not found
# Processing event 81 / 1386 [ETA: 0 s]
# Event 81 not found
# Processing event 82 / 1386 [ETA: 0 s]
# Event 82 not found
# Processing event 83 / 1386 [ETA: 0 s]
# Event 83 not found
# Processing event 84 / 1386 [ETA: 0 s]
# Event 84 not found
# Processing event 85 / 1386 [ETA: 0 s]
# Event 85 not found
# Processing event 86 / 1386 [ETA: 0 s]
# Event 86 not found
# Processing event 87 / 1386 [ETA: 0 s]
# Event 87 not found
# Processing event 88 / 1386 [ETA: 0 s]
# Event 88 not found
# Processing event 89 / 1386 [ETA: 0 s]
# Event 89 not found
# Processing event 90 / 1386 [ETA: 0 s]
# Event 90 not found
# Processing event 91 / 1386 [ETA: 0 s]
# Event 91 not found
# Processing event 92 / 1386 [ETA: 0 s]
# Event 92 not found
# Processing event 93 / 1386 [ETA: 0 s]
# Event 93 not found
# Processing event 94 / 1386 [ETA: 0 s]
# Event 94 not found
# Processing event 95 / 1386 [ETA: 0 s]
# Event 95 not found
# Processing event 96 / 1386 [ETA: 0 s]
# Event 96 not found
# Processing event 97 / 1386 [ETA: 0 s]
# Event 97 not found
# Processing event 98 / 1386 [ETA: 0 s]
# Event 98 not found
# Processing event 99 / 1386 [ETA: 0 s]
# Event 99 not found
# Processing event 100 / 1386 [ETA: 0 s]
# Event 100 not found
# Processing event 101 / 1386 [ETA: 0 s]
# Event 101 not found
# Processing event 102 / 1386 [ETA: 0 s]
# Event 102 not found
# Processing event 103 / 1386 [ETA: 0 s]
# Event 103 not found
# Processing event 104 / 1386 [ETA: 0 s]
# Event 104 not found
# Processing event 105 / 1386 [ETA: 0 s]
# Event 105 not found
# Processing event 106 / 1386 [ETA: 0 s]
# Event 106 not found
# Processing event 107 / 1386 [ETA: 0 s]
# Event 107 not found
# Processing event 108 / 1386 [ETA: 0 s]
# Event 108 not found
# Processing event 109 / 1386 [ETA: 0 s]
# Event 109 not found
# Processing event 110 / 1386 [ETA: 0 s]
# Event 110 not found
# Processing event 111 / 1386 [ETA: 0 s]
# Event 111 not found
# Processing event 112 / 1386 [ETA: 0 s]
# Event 112 not found
# Processing event 113 / 1386 [ETA: 0 s]
# Event 113 not found
# Processing event 114 / 1386 [ETA: 0 s]
# Event 114 not found
# Processing event 115 / 1386 [ETA: 0 s]
# Event 115 not found
# Processing event 116 / 1386 [ETA: 0 s]
# Event 116 not found
# Processing event 117 / 1386 [ETA: 0 s]
# Event 117 not found
# Processing event 118 / 1386 [ETA: 0 s]
# Event 118 not found
# Processing event 119 / 1386 [ETA: 0 s]
# Event 119 not found
# Processing event 120 / 1386 [ETA: 0 s]
# Event 120 not found
# Processing event 121 / 1386 [ETA: 0 s]
# Event 121 not found
# Processing event 122 / 1386 [ETA: 0 s]
# Event 122 not found
# Processing event 123 / 1386 [ETA: 0 s]
# Event 123 not found
# Processing event 124 / 1386 [ETA: 0 s]
# Event 124 not found
# Processing event 125 / 1386 [ETA: 0 s]
# Event 125 not found
# Processing event 126 / 1386 [ETA: 0 s]
# Event 126 not found
# Processing event 127 / 1386 [ETA: 0 s]
# Event 127 not found
# Processing event 128 / 1386 [ETA: 0 s]
# Event 128 not found
# Processing event 129 / 1386 [ETA: 0 s]
# Event 129 not found
# Processing event 130 / 1386 [ETA: 0 s]
# Event 130 not found
# Processing event 131 / 1386 [ETA: 0 s]
# Event 131 not found
# Processing event 132 / 1386 [ETA: 0 s]
# Event 132 not found
# Processing event 133 / 1386 [ETA: 0 s]
# Event 133 not found
# Processing event 134 / 1386 [ETA: 0 s]
# Event 134 not found
# Processing event 135 / 1386 [ETA: 0 s]
# Event 135 not found
# Processing event 136 / 1386 [ETA: 0 s]
# Event 136 not found
# Processing event 137 / 1386 [ETA: 0 s]
# Event 137 not found
# Processing event 138 / 1386 [ETA: 0 s]
# Event 138 not found
# Processing event 139 / 1386 [ETA: 0 s]
# Event 139 not found
# Processing event 140 / 1386 [ETA: 0 s]
# Event 140 not found
# Processing event 141 / 1386 [ETA: 0 s]
# Event 141 not found
# Processing event 142 / 1386 [ETA: 0 s]
# Event 142 not found
# Processing event 143 / 1386 [ETA: 0 s]
# Event 143 not found
# Processing event 144 / 1386 [ETA: 0 s]
# Event 144 not found
# Processing event 145 / 1386 [ETA: 0 s]
# Event 145 not found
# Processing event 146 / 1386 [ETA: 0 s]
# Event 146 not found
# Processing event 147 / 1386 [ETA: 0 s]
# Event 147 not found
# Processing event 148 / 1386 [ETA: 0 s]
# Event 148 not found
# Processing event 149 / 1386 [ETA: 0 s]
# Event 149 not found
# Processing event 150 / 1386 [ETA: 0 s]
# Event 150 not found
# Processing event 151 / 1386 [ETA: 0 s]
# Event 151 not found
# Processing event 152 / 1386 [ETA: 0 s]
# Event 152 not found
# Processing event 153 / 1386 [ETA: 0 s]
# Event 153 not found
# Processing event 154 / 1386 [ETA: 0 s]
# Event 154 not found
# Processing event 155 / 1386 [ETA: 0 s]
# Event 155 not found
# Processing event 156 / 1386 [ETA: 0 s]
# Event 156 not found
# Processing event 157 / 1386 [ETA: 0 s]
# Event 157 not found
# Processing event 158 / 1386 [ETA: 0 s]
# Event 158 not found
# Processing event 159 / 1386 [ETA: 0 s]
# Event 159 not found
# Processing event 160 / 1386 [ETA: 0 s]
# Event 160 not found
# Processing event 161 / 1386 [ETA: 0 s]
# Event 161 not found
# Processing event 162 / 1386 [ETA: 0 s]
# Event 162 not found
# Processing event 163 / 1386 [ETA: 0 s]
# Event 163 not found
# Processing event 164 / 1386 [ETA: 0 s]
# Event 164 not found
# Processing event 165 / 1386 [ETA: 0 s]
# Event 165 not found
# Processing event 166 / 1386 [ETA: 0 s]
# Event 166 not found
# Processing event 167 / 1386 [ETA: 0 s]
# Event 167 not found
# Processing event 168 / 1386 [ETA: 0 s]
# Event 168 not found
# Processing event 169 / 1386 [ETA: 0 s]
# Event 169 not found
# Processing event 170 / 1386 [ETA: 0 s]
# Event 170 not found
# Processing event 171 / 1386 [ETA: 0 s]
# Event 171 not found
# Processing event 172 / 1386 [ETA: 0 s]
# Event 172 not found
# Processing event 173 / 1386 [ETA: 0 s]
# Event 173 not found
# Processing event 174 / 1386 [ETA: 0 s]
# Event 174 not found
# Processing event 175 / 1386 [ETA: 0 s]
# Event 175 not found
# Processing event 176 / 1386 [ETA: 0 s]
# Event 176 not found
# Processing event 177 / 1386 [ETA: 0 s]
# Event 177 not found
# Processing event 178 / 1386 [ETA: 0 s]
# Event 178 not found
# Processing event 179 / 1386 [ETA: 0 s]
# Event 179 not found
# Processing event 180 / 1386 [ETA: 0 s]
# Event 180 not found
# Processing event 181 / 1386 [ETA: 0 s]
# Event 181 not found
# Processing event 182 / 1386 [ETA: 0 s]
# Event 182 not found
# Processing event 183 / 1386 [ETA: 0 s]
# Event 183 not found
# Processing event 184 / 1386 [ETA: 0 s]
# Event 184 not found
# Processing event 185 / 1386 [ETA: 0 s]
# Event 185 not found
# Processing event 186 / 1386 [ETA: 0 s]
# Event 186 not found
# Processing event 187 / 1386 [ETA: 0 s]
# Event 187 not found
# Processing event 188 / 1386 [ETA: 0 s]
# Event 188 not found
# Processing event 189 / 1386 [ETA: 0 s]
# Event 189 not found
# Processing event 190 / 1386 [ETA: 0 s]
# Event 190 not found
# Processing event 191 / 1386 [ETA: 0 s]
# Event 191 not found
# Processing event 192 / 1386 [ETA: 0 s]
# Event 192 not found
# Processing event 193 / 1386 [ETA: 0 s]
# Event 193 not found
# Processing event 194 / 1386 [ETA: 0 s]
# Event 194 not found
# Processing event 195 / 1386 [ETA: 0 s]
# Event 195 not found
# Processing event 196 / 1386 [ETA: 0 s]
# Event 196 not found
# Processing event 197 / 1386 [ETA: 0 s]
# Event 197 not found
# Processing event 198 / 1386 [ETA: 0 s]
# Event 198 not found
# Processing event 199 / 1386 [ETA: 0 s]
# Event 199 not found
# Processing event 200 / 1386 [ETA: 0 s]
# Event 200 not found
# Processing event 201 / 1386 [ETA: 0 s]
# Event 201 not found
# Processing event 202 / 1386 [ETA: 0 s]
# Event 202 not found
# Processing event 203 / 1386 [ETA: 0 s]
# Event 203 not found
# Processing event 204 / 1386 [ETA: 0 s]
# Event 204 not found
# Processing event 205 / 1386 [ETA: 0 s]
# Event 205 not found
# Processing event 206 / 1386 [ETA: 0 s]
# Event 206 not found
# Processing event 207 / 1386 [ETA: 0 s]
# Event 207 not found
# Processing event 208 / 1386 [ETA: 0 s]
# Event 208 not found
# Processing event 209 / 1386 [ETA: 0 s]
# Event 209 not found
# Processing event 210 / 1386 [ETA: 0 s]
# Event 210 not found
# Processing event 211 / 1386 [ETA: 0 s]
# Event 211 not found
# Processing event 212 / 1386 [ETA: 0 s]
# Event 212 not found
# Processing event 213 / 1386 [ETA: 0 s]
# Event 213 not found
# Processing event 214 / 1386 [ETA: 0 s]
# Event 214 not found
# Processing event 215 / 1386 [ETA: 0 s]
# Event 215 not found
# Processing event 216 / 1386 [ETA: 0 s]
# Event 216 not found
# Processing event 217 / 1386 [ETA: 0 s]
# Event 217 not found
# Processing event 218 / 1386 [ETA: 0 s]
# Event 218 not found
# Processing event 219 / 1386 [ETA: 0 s]
# Event 219 not found
# Processing event 220 / 1386 [ETA: 0 s]
# Event 220 not found
# Processing event 221 / 1386 [ETA: 0 s]
# Event 221 not found
# Processing event 222 / 1386 [ETA: 0 s]
# Event 222 not found
# Processing event 223 / 1386 [ETA: 0 s]
# Event 223 not found
# Processing event 224 / 1386 [ETA: 0 s]
# Event 224 not found
# Processing event 225 / 1386 [ETA: 0 s]
# Event 225 not found
# Processing event 226 / 1386 [ETA: 0 s]
# Event 226 not found
# Processing event 227 / 1386 [ETA: 0 s]
# Event 227 not found
# Processing event 228 / 1386 [ETA: 0 s]
# Event 228 not found
# Processing event 229 / 1386 [ETA: 0 s]
# Event 229 not found
# Processing event 230 / 1386 [ETA: 0 s]
# Event 230 not found
# Processing event 231 / 1386 [ETA: 0 s]
# Event 231 not found
# Processing event 232 / 1386 [ETA: 0 s]
# Event 232 not found
# Processing event 233 / 1386 [ETA: 0 s]
# Event 233 not found
# Processing event 234 / 1386 [ETA: 0 s]
# Event 234 not found
# Processing event 235 / 1386 [ETA: 0 s]
# Event 235 not found
# Processing event 236 / 1386 [ETA: 0 s]
# Event 236 not found
# Processing event 237 / 1386 [ETA: 0 s]
# Event 237 not found
# Processing event 238 / 1386 [ETA: 0 s]
# Event 238 not found
# Processing event 239 / 1386 [ETA: 0 s]
# Event 239 not found
# Processing event 240 / 1386 [ETA: 0 s]
# Event 240 not found
# Processing event 241 / 1386 [ETA: 0 s]
# Event 241 not found
# Processing event 242 / 1386 [ETA: 0 s]
# Event 242 not found
# Processing event 243 / 1386 [ETA: 0 s]
# Event 243 not found
# Processing event 244 / 1386 [ETA: 0 s]
# Event 244 not found
# Processing event 245 / 1386 [ETA: 0 s]
# Event 245 not found
# Processing event 246 / 1386 [ETA: 0 s]
# Event 246 not found
# Processing event 247 / 1386 [ETA: 0 s]
# Event 247 not found
# Processing event 248 / 1386 [ETA: 0 s]
# Event 248 not found
# Processing event 249 / 1386 [ETA: 0 s]
# Event 249 not found
# Processing event 250 / 1386 [ETA: 0 s]
# Event 250 not found
# Processing event 251 / 1386 [ETA: 0 s]
# Event 251 not found
# Processing event 252 / 1386 [ETA: 0 s]
# Event 252 not found
# Processing event 253 / 1386 [ETA: 0 s]
# Event 253 not found
# Processing event 254 / 1386 [ETA: 0 s]
# Event 254 not found
# Processing event 255 / 1386 [ETA: 0 s]
# Event 255 not found
# Processing event 256 / 1386 [ETA: 0 s]
# Event 256 not found
# Processing event 257 / 1386 [ETA: 0 s]
# Event 257 not found
# Processing event 258 / 1386 [ETA: 0 s]
# Event 258 not found
# Processing event 259 / 1386 [ETA: 0 s]
# Event 259 not found
# Processing event 260 / 1386 [ETA: 0 s]
# Event 260 not found
# Processing event 261 / 1386 [ETA: 0 s]
# Event 261 not found
# Processing event 262 / 1386 [ETA: 0 s]
# Event 262 not found
# Processing event 263 / 1386 [ETA: 0 s]
# Event 263 not found
# Processing event 264 / 1386 [ETA: 0 s]
# Event 264 not found
# Processing event 265 / 1386 [ETA: 0 s]
# Event 265 not found
# Processing event 266 / 1386 [ETA: 0 s]
# Event 266 not found
# Processing event 267 / 1386 [ETA: 0 s]
# Event 267 not found
# Processing event 268 / 1386 [ETA: 0 s]
# Event 268 not found
# Processing event 269 / 1386 [ETA: 0 s]
# Event 269 not found
# Processing event 270 / 1386 [ETA: 0 s]
# Event 270 not found
# Processing event 271 / 1386 [ETA: 0 s]
# Event 271 not found
# Processing event 272 / 1386 [ETA: 0 s]
# Event 272 not found
# Processing event 273 / 1386 [ETA: 0 s]
# Event 273 not found
# Processing event 274 / 1386 [ETA: 0 s]
# Event 274 not found
# Processing event 275 / 1386 [ETA: 0 s]
# Event 275 not found
# Processing event 276 / 1386 [ETA: 0 s]
# Event 276 not found
# Processing event 277 / 1386 [ETA: 0 s]
# Event 277 not found
# Processing event 278 / 1386 [ETA: 0 s]
# Event 278 not found
# Processing event 279 / 1386 [ETA: 0 s]
# Event 279 not found
# Processing event 280 / 1386 [ETA: 0 s]
# Event 280 not found
# Processing event 281 / 1386 [ETA: 0 s]
# Event 281 not found
# Processing event 282 / 1386 [ETA: 0 s]
# Event 282 not found
# Processing event 283 / 1386 [ETA: 0 s]
# Event 283 not found
# Processing event 284 / 1386 [ETA: 0 s]
# Event 284 not found
# Processing event 285 / 1386 [ETA: 0 s]
# Event 285 not found
# Processing event 286 / 1386 [ETA: 0 s]
# Event 286 not found
# Processing event 287 / 1386 [ETA: 0 s]
# Event 287 not found
# Processing event 288 / 1386 [ETA: 0 s]
# Event 288 not found
# Processing event 289 / 1386 [ETA: 0 s]
# Event 289 not found
# Processing event 290 / 1386 [ETA: 0 s]
# Event 290 not found
# Processing event 291 / 1386 [ETA: 0 s]
# Event 291 not found
# Processing event 292 / 1386 [ETA: 0 s]
# Event 292 not found
# Processing event 293 / 1386 [ETA: 0 s]
# Event 293 not found
# Processing event 294 / 1386 [ETA: 0 s]
# Event 294 not found
# Processing event 295 / 1386 [ETA: 0 s]
# Event 295 not found
# Processing event 296 / 1386 [ETA: 0 s]
# Event 296 not found
# Processing event 297 / 1386 [ETA: 0 s]
# Event 297 not found
# Processing event 298 / 1386 [ETA: 0 s]
# Event 298 not found
# Processing event 299 / 1386 [ETA: 0 s]
# Event 299 not found
# Processing event 300 / 1386 [ETA: 0 s]
# Event 300 not found
# Processing event 301 / 1386 [ETA: 0 s]
# Event 301 not found
# Processing event 302 / 1386 [ETA: 0 s]
# Event 302 not found
# Processing event 303 / 1386 [ETA: 0 s]
# Event 303 not found
# Processing event 304 / 1386 [ETA: 0 s]
# Event 304 not found
# Processing event 305 / 1386 [ETA: 0 s]
# Event 305 not found
# Processing event 306 / 1386 [ETA: 0 s]
# Event 306 not found
# Processing event 307 / 1386 [ETA: 0 s]
# Event 307 not found
# Processing event 308 / 1386 [ETA: 0 s]
# Event 308 not found
# Processing event 309 / 1386 [ETA: 0 s]
# Event 309 not found
# Processing event 310 / 1386 [ETA: 0 s]
# Event 310 not found
# Processing event 311 / 1386 [ETA: 0 s]
# Event 311 not found
# Processing event 312 / 1386 [ETA: 0 s]
# Event 312 not found
# Processing event 313 / 1386 [ETA: 0 s]
# Event 313 not found
# Processing event 314 / 1386 [ETA: 0 s]
# Event 314 not found
# Processing event 315 / 1386 [ETA: 0 s]
# Event 315 not found
# Processing event 316 / 1386 [ETA: 0 s]
# Event 316 not found
# Processing event 317 / 1386 [ETA: 0 s]
# Event 317 not found
# Processing event 318 / 1386 [ETA: 0 s]
# Event 318 not found
# Processing event 319 / 1386 [ETA: 0 s]
# Event 319 not found
# Processing event 320 / 1386 [ETA: 0 s]
# Event 320 not found
# Processing event 321 / 1386 [ETA: 0 s]
# Event 321 not found
# Processing event 322 / 1386 [ETA: 0 s]
# Event 322 not found
# Processing event 323 / 1386 [ETA: 0 s]
# Event 323 not found
# Processing event 324 / 1386 [ETA: 0 s]
# Event 324 not found
# Processing event 325 / 1386 [ETA: 0 s]
# Event 325 not found
# Processing event 326 / 1386 [ETA: 0 s]
# Event 326 not found
# Processing event 327 / 1386 [ETA: 0 s]
# Event 327 not found
# Processing event 328 / 1386 [ETA: 0 s]
# Event 328 not found
# Processing event 329 / 1386 [ETA: 0 s]
# Event 329 not found
# Processing event 330 / 1386 [ETA: 0 s]
# Event 330 not found
# Processing event 331 / 1386 [ETA: 0 s]
# Event 331 not found
# Processing event 332 / 1386 [ETA: 0 s]
# Event 332 not found
# Processing event 333 / 1386 [ETA: 0 s]
# Event 333 not found
# Processing event 334 / 1386 [ETA: 0 s]
# Event 334 not found
# Processing event 335 / 1386 [ETA: 0 s]
# Event 335 not found
# Processing event 336 / 1386 [ETA: 0 s]
# Event 336 not found
# Processing event 337 / 1386 [ETA: 0 s]
# Event 337 not found
# Processing event 338 / 1386 [ETA: 0 s]
# Event 338 not found
# Processing event 339 / 1386 [ETA: 0 s]
# Event 339 not found
# Processing event 340 / 1386 [ETA: 0 s]
# Event 340 not found
# Processing event 341 / 1386 [ETA: 0 s]
# Event 341 not found
# Processing event 342 / 1386 [ETA: 0 s]
# Event 342 not found
# Processing event 343 / 1386 [ETA: 0 s]
# Event 343 not found
# Processing event 344 / 1386 [ETA: 0 s]
# Event 344 not found
# Processing event 345 / 1386 [ETA: 0 s]
# Event 345 not found
# Processing event 346 / 1386 [ETA: 0 s]
# Event 346 not found
# Processing event 347 / 1386 [ETA: 0 s]
# Event 347 not found
# Processing event 348 / 1386 [ETA: 0 s]
# Event 348 not found
# Processing event 349 / 1386 [ETA: 0 s]
# Event 349 not found
# Processing event 350 / 1386 [ETA: 0 s]
# Event 350 not found
# Processing event 351 / 1386 [ETA: 0 s]
# Event 351 not found
# Processing event 352 / 1386 [ETA: 0 s]
# Event 352 not found
# Processing event 353 / 1386 [ETA: 0 s]
# Event 353 not found
# Processing event 354 / 1386 [ETA: 0 s]
# Event 354 not found
# Processing event 355 / 1386 [ETA: 0 s]
# Event 355 not found
# Processing event 356 / 1386 [ETA: 0 s]
# Event 356 not found
# Processing event 357 / 1386 [ETA: 0 s]
# Event 357 not found
# Processing event 358 / 1386 [ETA: 0 s]
# Event 358 not found
# Processing event 359 / 1386 [ETA: 0 s]
# Event 359 not found
# Processing event 360 / 1386 [ETA: 0 s]
# Event 360 not found
# Processing event 361 / 1386 [ETA: 0 s]
# Event 361 not found
# Processing event 362 / 1386 [ETA: 0 s]
# Event 362 not found
# Processing event 363 / 1386 [ETA: 0 s]
# Event 363 not found
# Processing event 364 / 1386 [ETA: 0 s]
# Event 364 not found
# Processing event 365 / 1386 [ETA: 0 s]
# Event 365 not found
# Processing event 366 / 1386 [ETA: 0 s]
# Event 366 not found
# Processing event 367 / 1386 [ETA: 0 s]
# Event 367 not found
# Processing event 368 / 1386 [ETA: 0 s]
# Event 368 not found
# Processing event 369 / 1386 [ETA: 0 s]
# Event 369 not found
# Processing event 370 / 1386 [ETA: 0 s]
# Event 370 not found
# Processing event 371 / 1386 [ETA: 0 s]
# Event 371 not found
# Processing event 372 / 1386 [ETA: 0 s]
# Event 372 not found
# Processing event 373 / 1386 [ETA: 0 s]
# Event 373 not found
# Processing event 374 / 1386 [ETA: 0 s]
# Event 374 not found
# Processing event 375 / 1386 [ETA: 0 s]
# Event 375 not found
# Processing event 376 / 1386 [ETA: 0 s]
# Event 376 not found
# Processing event 377 / 1386 [ETA: 0 s]
# Event 377 not found
# Processing event 378 / 1386 [ETA: 0 s]
# Event 378 not found
# Processing event 379 / 1386 [ETA: 0 s]
# Event 379 not found
# Processing event 380 / 1386 [ETA: 0 s]
# Event 380 not found
# Processing event 381 / 1386 [ETA: 0 s]
# Event 381 not found
# Processing event 382 / 1386 [ETA: 0 s]
# Event 382 not found
# Processing event 383 / 1386 [ETA: 0 s]
# Event 383 not found
# Processing event 384 / 1386 [ETA: 0 s]
# Event 384 not found
# Processing event 385 / 1386 [ETA: 0 s]
# Event 385 not found
# Processing event 386 / 1386 [ETA: 0 s]
# Event 386 not found
# Processing event 387 / 1386 [ETA: 0 s]
# Event 387 not found
# Processing event 388 / 1386 [ETA: 0 s]
# Event 388 not found
# Processing event 389 / 1386 [ETA: 0 s]
# Event 389 not found
# Processing event 390 / 1386 [ETA: 0 s]
# Event 390 not found
# Processing event 391 / 1386 [ETA: 0 s]
# Event 391 not found
# Processing event 392 / 1386 [ETA: 0 s]
# Event 392 not found
# Processing event 393 / 1386 [ETA: 0 s]
# Event 393 not found
# Processing event 394 / 1386 [ETA: 0 s]
# Event 394 not found
# Processing event 395 / 1386 [ETA: 0 s]
# Event 395 not found
# Processing event 396 / 1386 [ETA: 0 s]
# Event 396 not found
# Processing event 397 / 1386 [ETA: 0 s]
# Event 397 not found
# Processing event 398 / 1386 [ETA: 0 s]
# Event 398 not found
# Processing event 399 / 1386 [ETA: 0 s]
# Event 399 not found
# Processing event 400 / 1386 [ETA: 0 s]
# Event 400 not found
# Processing event 401 / 1386 [ETA: 0 s]
# Event 401 not found
# Processing event 402 / 1386 [ETA: 0 s]
# Event 402 not found
# Processing event 403 / 1386 [ETA: 0 s]
# Event 403 not found
# Processing event 404 / 1386 [ETA: 0 s]
# Event 404 not found
# Processing event 405 / 1386 [ETA: 0 s]
# Event 405 not found
# Processing event 406 / 1386 [ETA: 0 s]
# Event 406 not found
# Processing event 407 / 1386 [ETA: 0 s]
# Event 407 not found
# Processing event 408 / 1386 [ETA: 0 s]
# Event 408 not found
# Processing event 409 / 1386 [ETA: 0 s]
# Event 409 not found
# Processing event 410 / 1386 [ETA: 0 s]
# Event 410 not found
# Processing event 411 / 1386 [ETA: 0 s]
# Event 411 not found
# Processing event 412 / 1386 [ETA: 0 s]
# Event 412 not found
# Processing event 413 / 1386 [ETA: 0 s]
# Event 413 not found
# Processing event 414 / 1386 [ETA: 0 s]
# Event 414 not found
# Processing event 415 / 1386 [ETA: 0 s]
# Event 415 not found
# Processing event 416 / 1386 [ETA: 0 s]
# Event 416 not found
# Processing event 417 / 1386 [ETA: 0 s]
# Event 417 not found
# Processing event 418 / 1386 [ETA: 0 s]
# Event 418 not found
# Processing event 419 / 1386 [ETA: 0 s]
# Event 419 not found
# Processing event 420 / 1386 [ETA: 0 s]
# Event 420 not found
# Processing event 421 / 1386 [ETA: 0 s]
# Event 421 not found
# Processing event 422 / 1386 [ETA: 0 s]
# Event 422 not found
# Processing event 423 / 1386 [ETA: 0 s]
# Event 423 not found
# Processing event 424 / 1386 [ETA: 0 s]
# Event 424 not found
# Processing event 425 / 1386 [ETA: 0 s]
# Event 425 not found
# Processing event 426 / 1386 [ETA: 0 s]
# Event 426 not found
# Processing event 427 / 1386 [ETA: 0 s]
# Event 427 not found
# Processing event 428 / 1386 [ETA: 0 s]
# Event 428 not found
# Processing event 429 / 1386 [ETA: 0 s]
# Event 429 not found
# Processing event 430 / 1386 [ETA: 0 s]
# Event 430 not found
# Processing event 431 / 1386 [ETA: 0 s]
# Event 431 not found
# Processing event 432 / 1386 [ETA: 0 s]
# Event 432 not found
# Processing event 433 / 1386 [ETA: 0 s]
# Event 433 not found
# Processing event 434 / 1386 [ETA: 0 s]
# Event 434 not found
# Processing event 435 / 1386 [ETA: 0 s]
# Event 435 not found
# Processing event 436 / 1386 [ETA: 0 s]
# Event 436 not found
# Processing event 437 / 1386 [ETA: 0 s]
# Event 437 not found
# Processing event 438 / 1386 [ETA: 0 s]
# Event 438 not found
# Processing event 439 / 1386 [ETA: 0 s]
# Event 439 not found
# Processing event 440 / 1386 [ETA: 0 s]
# Event 440 not found
# Processing event 441 / 1386 [ETA: 0 s]
# Event 441 not found
# Processing event 442 / 1386 [ETA: 0 s]
# Event 442 not found
# Processing event 443 / 1386 [ETA: 0 s]
# Event 443 not found
# Processing event 444 / 1386 [ETA: 0 s]
# Event 444 not found
# Processing event 445 / 1386 [ETA: 0 s]
# Event 445 not found
# Processing event 446 / 1386 [ETA: 0 s]
# Event 446 not found
# Processing event 447 / 1386 [ETA: 0 s]
# Event 447 not found
# Processing event 448 / 1386 [ETA: 0 s]
# Event 448 not found
# Processing event 449 / 1386 [ETA: 0 s]
# Event 449 not found
# Processing event 450 / 1386 [ETA: 0 s]
# Event 450 not found
# Processing event 451 / 1386 [ETA: 0 s]
# Event 451 not found
# Processing event 452 / 1386 [ETA: 0 s]
# Event 452 not found
# Processing event 453 / 1386 [ETA: 0 s]
# Event 453 not found
# Processing event 454 / 1386 [ETA: 0 s]
# Event 454 not found
# Processing event 455 / 1386 [ETA: 0 s]
# Event 455 not found
# Processing event 456 / 1386 [ETA: 0 s]
# Event 456 not found
# Processing event 457 / 1386 [ETA: 0 s]
# Event 457 not found
# Processing event 458 / 1386 [ETA: 0 s]
# Event 458 not found
# Processing event 459 / 1386 [ETA: 0 s]
# Event 459 not found
# Processing event 460 / 1386 [ETA: 0 s]
# Event 460 not found
# Processing event 461 / 1386 [ETA: 0 s]
# Event 461 not found
# Processing event 462 / 1386 [ETA: 0 s]
# Event 462 not found
# Processing event 463 / 1386 [ETA: 0 s]
# Event 463 not found
# Processing event 464 / 1386 [ETA: 0 s]
# Event 464 not found
# Processing event 465 / 1386 [ETA: 0 s]
# Event 465 not found
# Processing event 466 / 1386 [ETA: 0 s]
# Event 466 not found
# Processing event 467 / 1386 [ETA: 0 s]
# Event 467 not found
# Processing event 468 / 1386 [ETA: 0 s]
# Event 468 not found
# Processing event 469 / 1386 [ETA: 0 s]
# Event 469 not found
# Processing event 470 / 1386 [ETA: 0 s]
# Event 470 not found
# Processing event 471 / 1386 [ETA: 0 s]
# Event 471 not found
# Processing event 472 / 1386 [ETA: 0 s]
# Event 472 not found
# Processing event 473 / 1386 [ETA: 0 s]
# Event 473 not found
# Processing event 474 / 1386 [ETA: 0 s]
# Event 474 not found
# Processing event 475 / 1386 [ETA: 0 s]
# Event 475 not found
# Processing event 476 / 1386 [ETA: 0 s]
# Event 476 not found
# Processing event 477 / 1386 [ETA: 0 s]
# Event 477 not found
# Processing event 478 / 1386 [ETA: 0 s]
# Event 478 not found
# Processing event 479 / 1386 [ETA: 0 s]
# Event 479 not found
# Processing event 480 / 1386 [ETA: 0 s]
# Event 480 not found
# Processing event 481 / 1386 [ETA: 0 s]
# Event 481 not found
# Processing event 482 / 1386 [ETA: 0 s]
# Event 482 not found
# Processing event 483 / 1386 [ETA: 0 s]
# Event 483 not found
# Processing event 484 / 1386 [ETA: 0 s]
# Event 484 not found
# Processing event 485 / 1386 [ETA: 0 s]
# Event 485 not found
# Processing event 486 / 1386 [ETA: 0 s]
# Event 486 not found
# Processing event 487 / 1386 [ETA: 0 s]
# Event 487 not found
# Processing event 488 / 1386 [ETA: 0 s]
# Event 488 not found
# Processing event 489 / 1386 [ETA: 0 s]
# Event 489 not found
# Processing event 490 / 1386 [ETA: 0 s]
# Event 490 not found
# Processing event 491 / 1386 [ETA: 0 s]
# Event 491 not found
# Processing event 492 / 1386 [ETA: 0 s]
# Event 492 not found
# Processing event 493 / 1386 [ETA: 0 s]
# Event 493 not found
# Processing event 494 / 1386 [ETA: 0 s]
# Event 494 not found
# Processing event 495 / 1386 [ETA: 0 s]
# Event 495 not found
# Processing event 496 / 1386 [ETA: 0 s]
# Event 496 not found
# Processing event 497 / 1386 [ETA: 0 s]
# Event 497 not found
# Processing event 498 / 1386 [ETA: 0 s]
# Event 498 not found
# Processing event 499 / 1386 [ETA: 0 s]
# Event 499 not found
# Processing event 500 / 1386 [ETA: 0 s]
# Event 500 not found
# Processing event 501 / 1386 [ETA: 0 s]
# Event 501 not found
# Processing event 502 / 1386 [ETA: 0 s]
# Event 502 not found
# Processing event 503 / 1386 [ETA: 0 s]
# Event 503 not found
# Processing event 504 / 1386 [ETA: 0 s]
# Event 504 not found
# Processing event 505 / 1386 [ETA: 0 s]
# Event 505 not found
# Processing event 506 / 1386 [ETA: 0 s]
# Event 506 not found
# Processing event 507 / 1386 [ETA: 0 s]
# Event 507 not found
# Processing event 508 / 1386 [ETA: 0 s]
# Event 508 not found
# Processing event 509 / 1386 [ETA: 0 s]
# Event 509 not found
# Processing event 510 / 1386 [ETA: 0 s]
# Event 510 not found
# Processing event 511 / 1386 [ETA: 0 s]
# Event 511 not found
# Processing event 512 / 1386 [ETA: 0 s]
# Event 512 not found
# Processing event 513 / 1386 [ETA: 0 s]
# Event 513 not found
# Processing event 514 / 1386 [ETA: 0 s]
# Event 514 not found
# Processing event 515 / 1386 [ETA: 0 s]
# Event 515 not found
# Processing event 516 / 1386 [ETA: 0 s]
# Event 516 not found
# Processing event 517 / 1386 [ETA: 0 s]
# Event 517 not found
# Processing event 518 / 1386 [ETA: 0 s]
# Event 518 not found
# Processing event 519 / 1386 [ETA: 0 s]
# Event 519 not found
# Processing event 520 / 1386 [ETA: 0 s]
# Event 520 not found
# Processing event 521 / 1386 [ETA: 0 s]
# Event 521 not found
# Processing event 522 / 1386 [ETA: 0 s]
# Event 522 not found
# Processing event 523 / 1386 [ETA: 0 s]
# Event 523 not found
# Processing event 524 / 1386 [ETA: 0 s]
# Event 524 not found
# Processing event 525 / 1386 [ETA: 0 s]
# Event 525 not found
# Processing event 526 / 1386 [ETA: 0 s]
# Event 526 not found
# Processing event 527 / 1386 [ETA: 0 s]
# Event 527 not found
# Processing event 528 / 1386 [ETA: 0 s]
# Event 528 not found
# Processing event 529 / 1386 [ETA: 0 s]
# Event 529 not found
# Processing event 530 / 1386 [ETA: 0 s]
# Event 530 not found
# Processing event 531 / 1386 [ETA: 0 s]
# Event 531 not found
# Processing event 532 / 1386 [ETA: 0 s]
# Event 532 not found
# Processing event 533 / 1386 [ETA: 0 s]
# Event 533 not found
# Processing event 534 / 1386 [ETA: 0 s]
# Event 534 not found
# Processing event 535 / 1386 [ETA: 0 s]
# Event 535 not found
# Processing event 536 / 1386 [ETA: 0 s]
# Event 536 not found
# Processing event 537 / 1386 [ETA: 0 s]
# Event 537 not found
# Processing event 538 / 1386 [ETA: 0 s]
# Event 538 not found
# Processing event 539 / 1386 [ETA: 0 s]
# Event 539 not found
# Processing event 540 / 1386 [ETA: 0 s]
# Event 540 not found
# Processing event 541 / 1386 [ETA: 0 s]
# Event 541 not found
# Processing event 542 / 1386 [ETA: 0 s]
# Event 542 not found
# Processing event 543 / 1386 [ETA: 0 s]
# Event 543 not found
# Processing event 544 / 1386 [ETA: 0 s]
# Event 544 not found
# Processing event 545 / 1386 [ETA: 0 s]
# Event 545 not found
# Processing event 546 / 1386 [ETA: 0 s]
# Event 546 not found
# Processing event 547 / 1386 [ETA: 0 s]
# Event 547 not found
# Processing event 548 / 1386 [ETA: 0 s]
# Event 548 not found
# Processing event 549 / 1386 [ETA: 0 s]
# Event 549 not found
# Processing event 550 / 1386 [ETA: 0 s]
# Event 550 not found
# Processing event 551 / 1386 [ETA: 0 s]
# Event 551 not found
# Processing event 552 / 1386 [ETA: 0 s]
# Event 552 not found
# Processing event 553 / 1386 [ETA: 0 s]
# Event 553 not found
# Processing event 554 / 1386 [ETA: 0 s]
# Event 554 not found
# Processing event 555 / 1386 [ETA: 0 s]
# Event 555 not found
# Processing event 556 / 1386 [ETA: 0 s]
# Event 556 not found
# Processing event 557 / 1386 [ETA: 0 s]
# Event 557 not found
# Processing event 558 / 1386 [ETA: 0 s]
# Event 558 not found
# Processing event 559 / 1386 [ETA: 0 s]
# Event 559 not found
# Processing event 560 / 1386 [ETA: 0 s]
# Event 560 not found
# Processing event 561 / 1386 [ETA: 0 s]
# Event 561 not found
# Processing event 562 / 1386 [ETA: 0 s]
# Event 562 not found
# Processing event 563 / 1386 [ETA: 0 s]
# Event 563 not found
# Processing event 564 / 1386 [ETA: 0 s]
# Event 564 not found
# Processing event 565 / 1386 [ETA: 0 s]
# Event 565 not found
# Processing event 566 / 1386 [ETA: 0 s]
# Event 566 not found
# Processing event 567 / 1386 [ETA: 0 s]
# Event 567 not found
# Processing event 568 / 1386 [ETA: 0 s]
# Event 568 not found
# Processing event 569 / 1386 [ETA: 0 s]
# Event 569 not found
# Processing event 570 / 1386 [ETA: 0 s]
# Event 570 not found
# Processing event 571 / 1386 [ETA: 0 s]
# Event 571 not found
# Processing event 572 / 1386 [ETA: 0 s]
# Event 572 not found
# Processing event 573 / 1386 [ETA: 0 s]
# Event 573 not found
# Processing event 574 / 1386 [ETA: 0 s]
# Event 574 not found
# Processing event 575 / 1386 [ETA: 0 s]
# Event 575 not found
# Processing event 576 / 1386 [ETA: 0 s]
# Event 576 not found
# Processing event 577 / 1386 [ETA: 0 s]
# Event 577 not found
# Processing event 578 / 1386 [ETA: 0 s]
# Event 578 not found
# Processing event 579 / 1386 [ETA: 0 s]
# Event 579 not found
# Processing event 580 / 1386 [ETA: 0 s]
# Event 580 not found
# Processing event 581 / 1386 [ETA: 0 s]
# Event 581 not found
# Processing event 582 / 1386 [ETA: 0 s]
# Event 582 not found
# Processing event 583 / 1386 [ETA: 0 s]
# Event 583 not found
# Processing event 584 / 1386 [ETA: 0 s]
# Event 584 not found
# Processing event 585 / 1386 [ETA: 0 s]
# Event 585 not found
# Processing event 586 / 1386 [ETA: 0 s]
# Event 586 not found
# Processing event 587 / 1386 [ETA: 0 s]
# Event 587 not found
# Processing event 588 / 1386 [ETA: 0 s]
# Event 588 not found
# Processing event 589 / 1386 [ETA: 0 s]
# Event 589 not found
# Processing event 590 / 1386 [ETA: 0 s]
# Event 590 not found
# Processing event 591 / 1386 [ETA: 0 s]
# Event 591 not found
# Processing event 592 / 1386 [ETA: 0 s]
# Event 592 not found
# Processing event 593 / 1386 [ETA: 0 s]
# Event 593 not found
# Processing event 594 / 1386 [ETA: 0 s]
# Event 594 not found
# Processing event 595 / 1386 [ETA: 0 s]
# Event 595 not found
# Processing event 596 / 1386 [ETA: 0 s]
# Event 596 not found
# Processing event 597 / 1386 [ETA: 0 s]
# Event 597 not found
# Processing event 598 / 1386 [ETA: 0 s]
# Event 598 not found
# Processing event 599 / 1386 [ETA: 0 s]
# Event 599 not found
# Processing event 600 / 1386 [ETA: 0 s]
# Event 600 not found
# Processing event 601 / 1386 [ETA: 0 s]
# Event 601 not found
# Processing event 602 / 1386 [ETA: 0 s]
# Event 602 not found
# Processing event 603 / 1386 [ETA: 0 s]
# Event 603 not found
# Processing event 604 / 1386 [ETA: 0 s]
# Event 604 not found
# Processing event 605 / 1386 [ETA: 0 s]
# Event 605 not found
# Processing event 606 / 1386 [ETA: 0 s]
# Event 606 not found
# Processing event 607 / 1386 [ETA: 0 s]
# Event 607 not found
# Processing event 608 / 1386 [ETA: 0 s]
# Event 608 not found
# Processing event 609 / 1386 [ETA: 0 s]
# Event 609 not found
# Processing event 610 / 1386 [ETA: 0 s]
# Event 610 not found
# Processing event 611 / 1386 [ETA: 0 s]
# Event 611 not found
# Processing event 612 / 1386 [ETA: 0 s]
# Event 612 not found
# Processing event 613 / 1386 [ETA: 0 s]
# Event 613 not found
# Processing event 614 / 1386 [ETA: 0 s]
# Event 614 not found
# Processing event 615 / 1386 [ETA: 0 s]
# Event 615 not found
# Processing event 616 / 1386 [ETA: 0 s]
# Event 616 not found
# Processing event 617 / 1386 [ETA: 0 s]
# Event 617 not found
# Processing event 618 / 1386 [ETA: 0 s]
# Event 618 not found
# Processing event 619 / 1386 [ETA: 0 s]
# Event 619 not found
# Processing event 620 / 1386 [ETA: 0 s]
# Event 620 not found
# Processing event 621 / 1386 [ETA: 0 s]
# Event 621 not found
# Processing event 622 / 1386 [ETA: 0 s]
# Event 622 not found
# Processing event 623 / 1386 [ETA: 0 s]
# Event 623 not found
# Processing event 624 / 1386 [ETA: 0 s]
# Event 624 not found
# Processing event 625 / 1386 [ETA: 0 s]
# Event 625 not found
# Processing event 626 / 1386 [ETA: 0 s]
# Event 626 not found
# Processing event 627 / 1386 [ETA: 0 s]
# Event 627 not found
# Processing event 628 / 1386 [ETA: 0 s]
# Event 628 not found
# Processing event 629 / 1386 [ETA: 0 s]
# Event 629 not found
# Processing event 630 / 1386 [ETA: 0 s]
# Event 630 not found
# Processing event 631 / 1386 [ETA: 0 s]
# Event 631 not found
# Processing event 632 / 1386 [ETA: 0 s]
# Event 632 not found
# Processing event 633 / 1386 [ETA: 0 s]
# Event 633 not found
# Processing event 634 / 1386 [ETA: 0 s]
# Event 634 not found
# Processing event 635 / 1386 [ETA: 0 s]
# Event 635 not found
# Processing event 636 / 1386 [ETA: 0 s]
# Event 636 not found
# Processing event 637 / 1386 [ETA: 0 s]
# Event 637 not found
# Processing event 638 / 1386 [ETA: 0 s]
# Event 638 not found
# Processing event 639 / 1386 [ETA: 0 s]
# Event 639 not found
# Processing event 640 / 1386 [ETA: 0 s]
# Event 640 not found
# Processing event 641 / 1386 [ETA: 0 s]
# Event 641 not found
# Processing event 642 / 1386 [ETA: 0 s]
# Event 642 not found
# Processing event 643 / 1386 [ETA: 0 s]
# Event 643 not found
# Processing event 644 / 1386 [ETA: 0 s]
# Event 644 not found
# Processing event 645 / 1386 [ETA: 0 s]
# Event 645 not found
# Processing event 646 / 1386 [ETA: 0 s]
# Event 646 not found
# Processing event 647 / 1386 [ETA: 0 s]
# Event 647 not found
# Processing event 648 / 1386 [ETA: 0 s]
# Event 648 not found
# Processing event 649 / 1386 [ETA: 0 s]
# Event 649 not found
# Processing event 650 / 1386 [ETA: 0 s]
# Event 650 not found
# Processing event 651 / 1386 [ETA: 0 s]
# Event 651 not found
# Processing event 652 / 1386 [ETA: 0 s]
# Event 652 not found
# Processing event 653 / 1386 [ETA: 0 s]
# Event 653 not found
# Processing event 654 / 1386 [ETA: 0 s]
# Event 654 not found
# Processing event 655 / 1386 [ETA: 0 s]
# Event 655 not found
# Processing event 656 / 1386 [ETA: 0 s]
# Event 656 not found
# Processing event 657 / 1386 [ETA: 0 s]
# Event 657 not found
# Processing event 658 / 1386 [ETA: 0 s]
# Event 658 not found
# Processing event 659 / 1386 [ETA: 0 s]
# Event 659 not found
# Processing event 660 / 1386 [ETA: 0 s]
# Event 660 not found
# Processing event 661 / 1386 [ETA: 0 s]
# Event 661 not found
# Processing event 662 / 1386 [ETA: 0 s]
# Event 662 not found
# Processing event 663 / 1386 [ETA: 0 s]
# Event 663 not found
# Processing event 664 / 1386 [ETA: 0 s]
# Event 664 not found
# Processing event 665 / 1386 [ETA: 0 s]
# Event 665 not found
# Processing event 666 / 1386 [ETA: 0 s]
# Event 666 not found
# Processing event 667 / 1386 [ETA: 0 s]
# Event 667 not found
# Processing event 668 / 1386 [ETA: 0 s]
# Event 668 not found
# Processing event 669 / 1386 [ETA: 0 s]
# Event 669 not found
# Processing event 670 / 1386 [ETA: 0 s]
# Event 670 not found
# Processing event 671 / 1386 [ETA: 0 s]
# Event 671 not found
# Processing event 672 / 1386 [ETA: 0 s]
# Event 672 not found
# Processing event 673 / 1386 [ETA: 0 s]
# Event 673 not found
# Processing event 674 / 1386 [ETA: 0 s]
# Event 674 not found
# Processing event 675 / 1386 [ETA: 0 s]
# Event 675 not found
# Processing event 676 / 1386 [ETA: 0 s]
# Event 676 not found
# Processing event 677 / 1386 [ETA: 0 s]
# Event 677 not found
# Processing event 678 / 1386 [ETA: 0 s]
# Event 678 not found
# Processing event 679 / 1386 [ETA: 0 s]
# Event 679 not found
# Processing event 680 / 1386 [ETA: 0 s]
# Event 680 not found
# Processing event 681 / 1386 [ETA: 0 s]
# Event 681 not found
# Processing event 682 / 1386 [ETA: 0 s]
# Event 682 not found
# Processing event 683 / 1386 [ETA: 0 s]
# Event 683 not found
# Processing event 684 / 1386 [ETA: 0 s]
# Event 684 not found
# Processing event 685 / 1386 [ETA: 0 s]
# Event 685 not found
# Processing event 686 / 1386 [ETA: 0 s]
# Event 686 not found
# Processing event 687 / 1386 [ETA: 0 s]
# Event 687 not found
# Processing event 688 / 1386 [ETA: 0 s]
# Event 688 not found
# Processing event 689 / 1386 [ETA: 0 s]
# Event 689 not found
# Processing event 690 / 1386 [ETA: 0 s]
# Event 690 not found
# Processing event 691 / 1386 [ETA: 0 s]
# Event 691 not found
# Processing event 692 / 1386 [ETA: 0 s]
# Event 692 not found
# Processing event 693 / 1386 [ETA: 0 s]
# Event 693 not found
# Processing event 694 / 1386 [ETA: 0 s]
# Event 694 not found
# Processing event 695 / 1386 [ETA: 0 s]
# Event 695 not found
# Processing event 696 / 1386 [ETA: 0 s]
# Event 696 not found
# Processing event 697 / 1386 [ETA: 0 s]
# Event 697 not found
# Processing event 698 / 1386 [ETA: 0 s]
# Event 698 not found
# Processing event 699 / 1386 [ETA: 0 s]
# Event 699 not found
# Processing event 700 / 1386 [ETA: 0 s]
# Event 700 not found
# Processing event 701 / 1386 [ETA: 0 s]
# Event 701 not found
# Processing event 702 / 1386 [ETA: 0 s]
# Event 702 not found
# Processing event 703 / 1386 [ETA: 0 s]
# Event 703 not found
# Processing event 704 / 1386 [ETA: 0 s]
# Event 704 not found
# Processing event 705 / 1386 [ETA: 0 s]
# Event 705 not found
# Processing event 706 / 1386 [ETA: 0 s]
# Event 706 not found
# Processing event 707 / 1386 [ETA: 0 s]
# Event 707 not found
# Processing event 708 / 1386 [ETA: 0 s]
# Event 708 not found
# Processing event 709 / 1386 [ETA: 0 s]
# Event 709 not found
# Processing event 710 / 1386 [ETA: 0 s]
# Event 710 not found
# Processing event 711 / 1386 [ETA: 0 s]
# Event 711 not found
# Processing event 712 / 1386 [ETA: 0 s]
# Event 712 not found
# Processing event 713 / 1386 [ETA: 0 s]
# Event 713 not found
# Processing event 714 / 1386 [ETA: 0 s]
# Event 714 not found
# Processing event 715 / 1386 [ETA: 0 s]
# Event 715 not found
# Processing event 716 / 1386 [ETA: 0 s]
# Event 716 not found
# Processing event 717 / 1386 [ETA: 0 s]
# Event 717 not found
# Processing event 718 / 1386 [ETA: 0 s]
# Event 718 not found
# Processing event 719 / 1386 [ETA: 0 s]
# Event 719 not found
# Processing event 720 / 1386 [ETA: 0 s]
# Event 720 not found
# Processing event 721 / 1386 [ETA: 0 s]
# Event 721 not found
# Processing event 722 / 1386 [ETA: 0 s]
# Event 722 not found
# Processing event 723 / 1386 [ETA: 0 s]
# Event 723 not found
# Processing event 724 / 1386 [ETA: 0 s]
# Event 724 not found
# Processing event 725 / 1386 [ETA: 0 s]
# Event 725 not found
# Processing event 726 / 1386 [ETA: 0 s]
# Event 726 not found
# Processing event 727 / 1386 [ETA: 0 s]
# Event 727 not found
# Processing event 728 / 1386 [ETA: 0 s]
# Event 728 not found
# Processing event 729 / 1386 [ETA: 0 s]
# Event 729 not found
# Processing event 730 / 1386 [ETA: 0 s]
# Event 730 not found
# Processing event 731 / 1386 [ETA: 0 s]
# Event 731 not found
# Processing event 732 / 1386 [ETA: 0 s]
# Event 732 not found
# Processing event 733 / 1386 [ETA: 0 s]
# Event 733 not found
# Processing event 734 / 1386 [ETA: 0 s]
# Event 734 not found
# Processing event 735 / 1386 [ETA: 0 s]
# Event 735 not found
# Processing event 736 / 1386 [ETA: 0 s]
# Event 736 not found
# Processing event 737 / 1386 [ETA: 0 s]
# Event 737 not found
# Processing event 738 / 1386 [ETA: 0 s]
# Event 738 not found
# Processing event 739 / 1386 [ETA: 0 s]
# Event 739 not found
# Processing event 740 / 1386 [ETA: 0 s]
# Event 740 not found
# Processing event 741 / 1386 [ETA: 0 s]
# Event 741 not found
# Processing event 742 / 1386 [ETA: 0 s]
# Event 742 not found
# Processing event 743 / 1386 [ETA: 0 s]
# Event 743 not found
# Processing event 744 / 1386 [ETA: 0 s]
# Event 744 not found
# Processing event 745 / 1386 [ETA: 0 s]
# Event 745 not found
# Processing event 746 / 1386 [ETA: 0 s]
# Event 746 not found
# Processing event 747 / 1386 [ETA: 0 s]
# Event 747 not found
# Processing event 748 / 1386 [ETA: 0 s]
# Event 748 not found
# Processing event 749 / 1386 [ETA: 0 s]
# Event 749 not found
# Processing event 750 / 1386 [ETA: 0 s]
# Event 750 not found
# Processing event 751 / 1386 [ETA: 0 s]
# Event 751 not found
# Processing event 752 / 1386 [ETA: 0 s]
# Event 752 not found
# Processing event 753 / 1386 [ETA: 0 s]
# Event 753 not found
# Processing event 754 / 1386 [ETA: 0 s]
# Event 754 not found
# Processing event 755 / 1386 [ETA: 0 s]
# Event 755 not found
# Processing event 756 / 1386 [ETA: 0 s]
# Event 756 not found
# Processing event 757 / 1386 [ETA: 0 s]
# Event 757 not found
# Processing event 758 / 1386 [ETA: 0 s]
# Event 758 not found
# Processing event 759 / 1386 [ETA: 0 s]
# Event 759 not found
# Processing event 760 / 1386 [ETA: 0 s]
# Event 760 not found
# Processing event 761 / 1386 [ETA: 0 s]
# Event 761 not found
# Processing event 762 / 1386 [ETA: 0 s]
# Event 762 not found
# Processing event 763 / 1386 [ETA: 0 s]
# Event 763 not found
# Processing event 764 / 1386 [ETA: 0 s]
# Event 764 not found
# Processing event 765 / 1386 [ETA: 0 s]
# Event 765 not found
# Processing event 766 / 1386 [ETA: 0 s]
# Event 766 not found
# Processing event 767 / 1386 [ETA: 0 s]
# Event 767 not found
# Processing event 768 / 1386 [ETA: 0 s]
# Event 768 not found
# Processing event 769 / 1386 [ETA: 0 s]
# Event 769 not found
# Processing event 770 / 1386 [ETA: 0 s]
# Event 770 not found
# Processing event 771 / 1386 [ETA: 0 s]
# Event 771 not found
# Processing event 772 / 1386 [ETA: 0 s]
# Event 772 not found
# Processing event 773 / 1386 [ETA: 0 s]
# Event 773 not found
# Processing event 774 / 1386 [ETA: 0 s]
# Event 774 not found
# Processing event 775 / 1386 [ETA: 0 s]
# Event 775 not found
# Processing event 776 / 1386 [ETA: 0 s]
# Event 776 not found
# Processing event 777 / 1386 [ETA: 0 s]
# Event 777 not found
# Processing event 778 / 1386 [ETA: 0 s]
# Event 778 not found
# Processing event 779 / 1386 [ETA: 0 s]
# Event 779 not found
# Processing event 780 / 1386 [ETA: 0 s]
# Event 780 not found
# Processing event 781 / 1386 [ETA: 0 s]
# Event 781 not found
# Processing event 782 / 1386 [ETA: 0 s]
# Event 782 not found
# Processing event 783 / 1386 [ETA: 0 s]
# Event 783 not found
# Processing event 784 / 1386 [ETA: 0 s]
# Event 784 not found
# Processing event 785 / 1386 [ETA: 0 s]
# Event 785 not found
# Processing event 786 / 1386 [ETA: 0 s]
# Event 786 not found
# Processing event 787 / 1386 [ETA: 0 s]
# Event 787 not found
# Processing event 788 / 1386 [ETA: 0 s]
# Event 788 not found
# Processing event 789 / 1386 [ETA: 0 s]
# Event 789 not found
# Processing event 790 / 1386 [ETA: 0 s]
# Event 790 not found
# Processing event 791 / 1386 [ETA: 0 s]
# Event 791 not found
# Processing event 792 / 1386 [ETA: 0 s]
# Event 792 not found
# Processing event 793 / 1386 [ETA: 0 s]
# Event 793 not found
# Processing event 794 / 1386 [ETA: 0 s]
# Event 794 not found
# Processing event 795 / 1386 [ETA: 0 s]
# Event 795 not found
# Processing event 796 / 1386 [ETA: 0 s]
# Event 796 not found
# Processing event 797 / 1386 [ETA: 0 s]
# Event 797 not found
# Processing event 798 / 1386 [ETA: 0 s]
# Event 798 not found
# Processing event 799 / 1386 [ETA: 0 s]
# Event 799 not found
# Processing event 800 / 1386 [ETA: 0 s]
# Event 800 not found
# Processing event 801 / 1386 [ETA: 0 s]
# Event 801 not found
# Processing event 802 / 1386 [ETA: 0 s]
# Event 802 not found
# Processing event 803 / 1386 [ETA: 0 s]
# Event 803 not found
# Processing event 804 / 1386 [ETA: 0 s]
# Event 804 not found
# Processing event 805 / 1386 [ETA: 0 s]
# Event 805 not found
# Processing event 806 / 1386 [ETA: 0 s]
# Event 806 not found
# Processing event 807 / 1386 [ETA: 0 s]
# Event 807 not found
# Processing event 808 / 1386 [ETA: 0 s]
# Event 808 not found
# Processing event 809 / 1386 [ETA: 0 s]
# Event 809 not found
# Processing event 810 / 1386 [ETA: 0 s]
# Event 810 not found
# Processing event 811 / 1386 [ETA: 0 s]
# Event 811 not found
# Processing event 812 / 1386 [ETA: 0 s]
# Event 812 not found
# Processing event 813 / 1386 [ETA: 0 s]
# Event 813 not found
# Processing event 814 / 1386 [ETA: 0 s]
# Event 814 not found
# Processing event 815 / 1386 [ETA: 0 s]
# Event 815 not found
# Processing event 816 / 1386 [ETA: 0 s]
# Event 816 not found
# Processing event 817 / 1386 [ETA: 0 s]
# Event 817 not found
# ...
# Processing event 1125 / 1386 [ETA: 0 s]
# Event 1125 not found
# Processing event 1126 / 1386 [ETA: 0 s]
# Event 1126 not found
# Processing event 1127 / 1386 [ETA: 0 s]
# Event 1127 not found
# Processing event 1128 / 1386 [ETA: 0 s]
# Event 1128 not found
# Processing event 1129 / 1386 [ETA: 0 s]
# Event 1129 not found
# Processing event 1130 / 1386 [ETA: 0 s]
# Event 1130 not found
# Processing event 1131 / 1386 [ETA: 0 s]
# Event 1131 not found
# Processing event 1132 / 1386 [ETA: 0 s]
# Event 1132 not found
# Processing event 1133 / 1386 [ETA: 0 s]
# Event 1133 not found
# Processing event 1134 / 1386 [ETA: 0 s]
# Event 1134 not found
# Processing event 1135 / 1386 [ETA: 0 s]
# Event 1135 not found
# Processing event 1136 / 1386 [ETA: 0 s]
# Event 1136 not found
# Processing event 1137 / 1386 [ETA: 0 s]
# Event 1137 not found
# Processing event 1138 / 1386 [ETA: 0 s]
# Event 1138 not found
# Processing event 1139 / 1386 [ETA: 0 s]
# Event 1139 not found
# Processing event 1140 / 1386 [ETA: 0 s]
# Event 1140 not found
# Processing event 1141 / 1386 [ETA: 0 s]
# Event 1141 not found
# Processing event 1142 / 1386 [ETA: 0 s]
# Event 1142 not found
# Processing event 1143 / 1386 [ETA: 0 s]
# Event 1143 not found
# Processing event 1144 / 1386 [ETA: 0 s]
# Event 1144 not found
# Processing event 1145 / 1386 [ETA: 0 s]
# Event 1145 not found
# Processing event 1146 / 1386 [ETA: 0 s]
# Event 1146 not found
# Processing event 1147 / 1386 [ETA: 0 s]
# Event 1147 not found
# Processing event 1148 / 1386 [ETA: 0 s]
# Event 1148 not found
# Processing event 1149 / 1386 [ETA: 0 s]
# Event 1149 not found
# Processing event 1150 / 1386 [ETA: 0 s]
# Event 1150 not found
# Processing event 1151 / 1386 [ETA: 0 s]
# Event 1151 not found
# Processing event 1152 / 1386 [ETA: 0 s]
# Event 1152 not found
# Processing event 1153 / 1386 [ETA: 0 s]
# Event 1153 not found
# Processing event 1154 / 1386 [ETA: 0 s]
# Event 1154 not found
# Processing event 1155 / 1386 [ETA: 0 s]
# Event 1155 not found
# Processing event 1156 / 1386 [ETA: 0 s]
# Event 1156 not found
# Processing event 1157 / 1386 [ETA: 0 s]
# Event 1157 not found
# Processing event 1158 / 1386 [ETA: 0 s]
# Event 1158 not found
# Processing event 1159 / 1386 [ETA: 0 s]
# Event 1159 not found
# Processing event 1160 / 1386 [ETA: 0 s]
# Event 1160 not found
# Processing event 1161 / 1386 [ETA: 0 s]
# Event 1161 not found
# Processing event 1162 / 1386 [ETA: 0 s]
# Event 1162 not found
# Processing event 1163 / 1386 [ETA: 0 s]
# Event 1163 not found
# Processing event 1164 / 1386 [ETA: 0 s]
# Event 1164 not found
# Processing event 1165 / 1386 [ETA: 0 s]
# Event 1165 not found
# Processing event 1166 / 1386 [ETA: 0 s]
# Event 1166 not found
# Processing event 1167 / 1386 [ETA: 0 s]
# Event 1167 not found
# Processing event 1168 / 1386 [ETA: 0 s]
# Event 1168 not found
# Processing event 1169 / 1386 [ETA: 0 s]
# Event 1169 not found
# Processing event 1170 / 1386 [ETA: 0 s]
# Event 1170 not found
# Processing event 1171 / 1386 [ETA: 0 s]
# Event 1171 not found
# Processing event 1172 / 1386 [ETA: 0 s]
# Event 1172 not found
# Processing event 1173 / 1386 [ETA: 0 s]
# Event 1173 not found
# Processing event 1174 / 1386 [ETA: 0 s]
# Event 1174 not found
# Processing event 1175 / 1386 [ETA: 0 s]
# Event 1175 not found
# Processing event 1176 / 1386 [ETA: 0 s]
# Event 1176 not found
# Processing event 1177 / 1386 [ETA: 0 s]
# Event 1177 not found
# Processing event 1178 / 1386 [ETA: 0 s]
# Event 1178 not found
# Processing event 1179 / 1386 [ETA: 0 s]
# Event 1179 not found
# Processing event 1180 / 1386 [ETA: 0 s]
# Event 1180 not found
# Processing event 1181 / 1386 [ETA: 0 s]
# Event 1181 not found
# Processing event 1182 / 1386 [ETA: 0 s]
# Event 1182 not found
# Processing event 1183 / 1386 [ETA: 0 s]
# Event 1183 not found
# Processing event 1184 / 1386 [ETA: 0 s]
# Event 1184 not found
# Processing event 1185 / 1386 [ETA: 0 s]
# Event 1185 not found
# Processing event 1186 / 1386 [ETA: 0 s]
# Event 1186 not found
# Processing event 1187 / 1386 [ETA: 0 s]
# Event 1187 not found
# Processing event 1188 / 1386 [ETA: 0 s]
# Event 1188 not found
# Processing event 1189 / 1386 [ETA: 0 s]
# Event 1189 not found
# Processing event 1190 / 1386 [ETA: 0 s]
# Event 1190 not found
# Processing event 1191 / 1386 [ETA: 0 s]
# Event 1191 not found
# Processing event 1192 / 1386 [ETA: 0 s]
# Event 1192 not found
# Processing event 1193 / 1386 [ETA: 0 s]
# Event 1193 not found
# Processing event 1194 / 1386 [ETA: 0 s]
# Event 1194 not found
# Processing event 1195 / 1386 [ETA: 0 s]
# Event 1195 not found
# Processing event 1196 / 1386 [ETA: 0 s]
# Event 1196 not found
# Processing event 1197 / 1386 [ETA: 0 s]
# Event 1197 not found
# Processing event 1198 / 1386 [ETA: 0 s]
# Event 1198 not found
# Processing event 1199 / 1386 [ETA: 0 s]
# Event 1199 not found
# Processing event 1200 / 1386 [ETA: 0 s]
# Event 1200 not found
# Processing event 1201 / 1386 [ETA: 0 s]
# Event 1201 not found
# Processing event 1202 / 1386 [ETA: 0 s]
# Event 1202 not found
# Processing event 1203 / 1386 [ETA: 0 s]
# Event 1203 not found
# Processing event 1204 / 1386 [ETA: 0 s]
# Event 1204 not found
# Processing event 1205 / 1386 [ETA: 0 s]
# Event 1205 not found
# Processing event 1206 / 1386 [ETA: 0 s]
# Event 1206 not found
# Processing event 1207 / 1386 [ETA: 0 s]
# Event 1207 not found
# Processing event 1208 / 1386 [ETA: 0 s]
# Event 1208 not found
# Processing event 1209 / 1386 [ETA: 0 s]
# Event 1209 not found
# Processing event 1210 / 1386 [ETA: 0 s]
# Event 1210 not found
# Processing event 1211 / 1386 [ETA: 0 s]
# Event 1211 not found
# Processing event 1212 / 1386 [ETA: 0 s]
# Event 1212 not found
# Processing event 1213 / 1386 [ETA: 0 s]
# Event 1213 not found
# Processing event 1214 / 1386 [ETA: 0 s]
# Event 1214 not found
# Processing event 1215 / 1386 [ETA: 0 s]
# Event 1215 not found
# Processing event 1216 / 1386 [ETA: 0 s]
# Event 1216 not found
# Processing event 1217 / 1386 [ETA: 0 s]
# Event 1217 not found
# Processing event 1218 / 1386 [ETA: 0 s]
# Event 1218 not found
# Processing event 1219 / 1386 [ETA: 0 s]
# Event 1219 not found
# Processing event 1220 / 1386 [ETA: 0 s]
# Event 1220 not found
# Processing event 1221 / 1386 [ETA: 0 s]
# Event 1221 not found
# Processing event 1222 / 1386 [ETA: 0 s]
# Event 1222 not found
# Processing event 1223 / 1386 [ETA: 0 s]
# Event 1223 not found
# Processing event 1224 / 1386 [ETA: 0 s]
# Event 1224 not found
# Processing event 1225 / 1386 [ETA: 0 s]
# Event 1225 not found
# Processing event 1226 / 1386 [ETA: 0 s]
# Event 1226 not found
# Processing event 1227 / 1386 [ETA: 0 s]
# Event 1227 not found
# Processing event 1228 / 1386 [ETA: 0 s]
# Event 1228 not found
# Processing event 1229 / 1386 [ETA: 0 s]
# Event 1229 not found
# Processing event 1230 / 1386 [ETA: 0 s]
# Event 1230 not found
# Processing event 1231 / 1386 [ETA: 0 s]
# Event 1231 not found
# Processing event 1232 / 1386 [ETA: 0 s]
# Event 1232 not found
# Processing event 1233 / 1386 [ETA: 0 s]
# Event 1233 not found
# Processing event 1234 / 1386 [ETA: 0 s]
# Event 1234 not found
# Processing event 1235 / 1386 [ETA: 0 s]
# Event 1235 not found
# Processing event 1236 / 1386 [ETA: 0 s]
# Event 1236 not found
# Processing event 1237 / 1386 [ETA: 0 s]
# Event 1237 not found
# Processing event 1238 / 1386 [ETA: 0 s]
# Event 1238 not found
# Processing event 1239 / 1386 [ETA: 0 s]
# Event 1239 not found
# Processing event 1240 / 1386 [ETA: 0 s]
# Event 1240 not found
# Processing event 1241 / 1386 [ETA: 0 s]
# Event 1241 not found
# Processing event 1242 / 1386 [ETA: 0 s]
# Event 1242 not found
# Processing event 1243 / 1386 [ETA: 0 s]
# Event 1243 not found
# Processing event 1244 / 1386 [ETA: 0 s]
# Event 1244 not found
# Processing event 1245 / 1386 [ETA: 0 s]
# Event 1245 not found
# Processing event 1246 / 1386 [ETA: 0 s]
# Event 1246 not found
# Processing event 1247 / 1386 [ETA: 0 s]
# Event 1247 not found
# Processing event 1248 / 1386 [ETA: 0 s]
# Event 1248 not found
# Processing event 1249 / 1386 [ETA: 0 s]
# Event 1249 not found
# Processing event 1250 / 1386 [ETA: 0 s]
# Event 1250 not found
# Processing event 1251 / 1386 [ETA: 0 s]
# Event 1251 not found
# Processing event 1252 / 1386 [ETA: 0 s]
# Event 1252 not found
# Processing event 1253 / 1386 [ETA: 0 s]
# Event 1253 not found
# Processing event 1254 / 1386 [ETA: 0 s]
# Event 1254 not found
# Processing event 1255 / 1386 [ETA: 0 s]
# Event 1255 not found
# Processing event 1256 / 1386 [ETA: 0 s]
# Event 1256 not found
# Processing event 1257 / 1386 [ETA: 0 s]
# Event 1257 not found
# Processing event 1258 / 1386 [ETA: 0 s]
# Event 1258 not found
# Processing event 1259 / 1386 [ETA: 0 s]
# Event 1259 not found
# Processing event 1260 / 1386 [ETA: 0 s]
# Event 1260 not found
# Processing event 1261 / 1386 [ETA: 0 s]
# Event 1261 not found
# Processing event 1262 / 1386 [ETA: 0 s]
# Event 1262 not found
# Processing event 1263 / 1386 [ETA: 0 s]
# Event 1263 not found
# Processing event 1264 / 1386 [ETA: 0 s]
# Event 1264 not found
# Processing event 1265 / 1386 [ETA: 0 s]
# Event 1265 not found
# Processing event 1266 / 1386 [ETA: 0 s]
# Event 1266 not found
# Processing event 1267 / 1386 [ETA: 0 s]
# Event 1267 not found
# Processing event 1268 / 1386 [ETA: 0 s]
# Event 1268 not found
# Processing event 1269 / 1386 [ETA: 0 s]
# Event 1269 not found
# Processing event 1270 / 1386 [ETA: 0 s]
# Event 1270 not found
# Processing event 1271 / 1386 [ETA: 0 s]
# Event 1271 not found
# Processing event 1272 / 1386 [ETA: 0 s]
# Event 1272 not found
# Processing event 1273 / 1386 [ETA: 0 s]
# Event 1273 not found
# Processing event 1274 / 1386 [ETA: 0 s]
# Event 1274 not found
# Processing event 1275 / 1386 [ETA: 0 s]
# Event 1275 not found
# Processing event 1276 / 1386 [ETA: 0 s]
# Event 1276 not found
# Processing event 1277 / 1386 [ETA: 0 s]
# Event 1277 not found
# Processing event 1278 / 1386 [ETA: 0 s]
# Event 1278 not found
# Processing event 1279 / 1386 [ETA: 0 s]
# Event 1279 not found
# Processing event 1280 / 1386 [ETA: 0 s]
# Event 1280 not found
# Processing event 1281 / 1386 [ETA: 0 s]
# Event 1281 not found
# Processing event 1282 / 1386 [ETA: 0 s]
# Event 1282 not found
# Processing event 1283 / 1386 [ETA: 0 s]
# Event 1283 not found
# Processing event 1284 / 1386 [ETA: 0 s]
# Event 1284 not found
# Processing event 1285 / 1386 [ETA: 0 s]
# Event 1285 not found
# Processing event 1286 / 1386 [ETA: 0 s]
# Event 1286 not found
# Processing event 1287 / 1386 [ETA: 0 s]
# Event 1287 not found
# Processing event 1288 / 1386 [ETA: 0 s]
# Event 1288 not found
# Processing event 1289 / 1386 [ETA: 0 s]
# Event 1289 not found
# Processing event 1290 / 1386 [ETA: 0 s]
# Event 1290 not found
# Processing event 1291 / 1386 [ETA: 0 s]
# Event 1291 not found
# Processing event 1292 / 1386 [ETA: 0 s]
# Event 1292 not found
# Processing event 1293 / 1386 [ETA: 0 s]
# Event 1293 not found
# Processing event 1294 / 1386 [ETA: 0 s]
# Event 1294 not found
# Processing event 1295 / 1386 [ETA: 0 s]
# Event 1295 not found
# Processing event 1296 / 1386 [ETA: 0 s]
# Event 1296 not found
# Processing event 1297 / 1386 [ETA: 0 s]
# Event 1297 not found
# Processing event 1298 / 1386 [ETA: 0 s]
# Event 1298 not found
# Processing event 1299 / 1386 [ETA: 0 s]
# Event 1299 not found
# Processing event 1300 / 1386 [ETA: 0 s]
# Event 1300 not found
# Processing event 1301 / 1386 [ETA: 0 s]
# Event 1301 not found
# Processing event 1302 / 1386 [ETA: 0 s]
# Event 1302 not found
# Processing event 1303 / 1386 [ETA: 0 s]
# Event 1303 not found
# Processing event 1304 / 1386 [ETA: 0 s]
# Event 1304 not found
# Processing event 1305 / 1386 [ETA: 0 s]
# Event 1305 not found
# Processing event 1306 / 1386 [ETA: 0 s]
# Event 1306 not found
# Processing event 1307 / 1386 [ETA: 0 s]
# Event 1307 not found
# Processing event 1308 / 1386 [ETA: 0 s]
# Event 1308 not found
# Processing event 1309 / 1386 [ETA: 0 s]
# Event 1309 not found
# Processing event 1310 / 1386 [ETA: 0 s]
# Event 1310 not found
# Processing event 1311 / 1386 [ETA: 0 s]
# Event 1311 not found
# Processing event 1312 / 1386 [ETA: 0 s]
# Event 1312 not found
# Processing event 1313 / 1386 [ETA: 0 s]
# Event 1313 not found
# Processing event 1314 / 1386 [ETA: 0 s]
# Event 1314 not found
# Processing event 1315 / 1386 [ETA: 0 s]
# Event 1315 not found
# Processing event 1316 / 1386 [ETA: 0 s]
# Event 1316 not found
# Processing event 1317 / 1386 [ETA: 0 s]
# Event 1317 not found
# Processing event 1318 / 1386 [ETA: 0 s]
# Event 1318 not found
# Processing event 1319 / 1386 [ETA: 0 s]
# Event 1319 not found
# Processing event 1320 / 1386 [ETA: 0 s]
# Event 1320 not found
# Processing event 1321 / 1386 [ETA: 0 s]
# Event 1321 not found
# Processing event 1322 / 1386 [ETA: 0 s]
# Event 1322 not found
# Processing event 1323 / 1386 [ETA: 0 s]
# Event 1323 not found
# Processing event 1324 / 1386 [ETA: 0 s]
# Event 1324 not found
# Processing event 1325 / 1386 [ETA: 0 s]
# Event 1325 not found
# Processing event 1326 / 1386 [ETA: 0 s]
# Event 1326 not found
# Processing event 1327 / 1386 [ETA: 0 s]
# Event 1327 not found
# Processing event 1328 / 1386 [ETA: 0 s]
# Event 1328 not found
# Processing event 1329 / 1386 [ETA: 0 s]
# Event 1329 not found
# Processing event 1330 / 1386 [ETA: 0 s]
# Event 1330 not found
# Processing event 1331 / 1386 [ETA: 0 s]
# Event 1331 not found
# Processing event 1332 / 1386 [ETA: 0 s]
# Event 1332 not found
# Processing event 1333 / 1386 [ETA: 0 s]
# Event 1333 not found
# Processing event 1334 / 1386 [ETA: 0 s]
# Event 1334 not found
# Processing event 1335 / 1386 [ETA: 0 s]
# Event 1335 not found
# Processing event 1336 / 1386 [ETA: 0 s]
# Event 1336 not found
# Processing event 1337 / 1386 [ETA: 0 s]
# Event 1337 not found
# Processing event 1338 / 1386 [ETA: 0 s]
# Event 1338 not found
# Processing event 1339 / 1386 [ETA: 0 s]
# Event 1339 not found
# Processing event 1340 / 1386 [ETA: 0 s]
# Event 1340 not found
# Processing event 1341 / 1386 [ETA: 0 s]
# Event 1341 not found
# Processing event 1342 / 1386 [ETA: 0 s]
# Event 1342 not found
# Processing event 1343 / 1386 [ETA: 0 s]
# Event 1343 not found
# Processing event 1344 / 1386 [ETA: 0 s]
# Event 1344 not found
# Processing event 1345 / 1386 [ETA: 0 s]
# Event 1345 not found
# Processing event 1346 / 1386 [ETA: 0 s]
# Event 1346 not found
# Processing event 1347 / 1386 [ETA: 0 s]
# Event 1347 not found
# Processing event 1348 / 1386 [ETA: 0 s]
# Event 1348 not found
# Processing event 1349 / 1386 [ETA: 0 s]
# Event 1349 not found
# Processing event 1350 / 1386 [ETA: 0 s]
# Event 1350 not found
# Processing event 1351 / 1386 [ETA: 0 s]
# Event 1351 not found
# Processing event 1352 / 1386 [ETA: 0 s]
# Event 1352 not found
# Processing event 1353 / 1386 [ETA: 0 s]
# Event 1353 not found
# Processing event 1354 / 1386 [ETA: 0 s]
# Event 1354 not found
# Processing event 1355 / 1386 [ETA: 0 s]
# Event 1355 not found
# Processing event 1356 / 1386 [ETA: 0 s]
# Event 1356 not found
# Processing event 1357 / 1386 [ETA: 0 s]
# Event 1357 not found
# Processing event 1358 / 1386 [ETA: 0 s]
# Event 1358 not found
# Processing event 1359 / 1386 [ETA: 0 s]
# Event 1359 not found
# Processing event 1360 / 1386 [ETA: 0 s]
# Event 1360 not found
# Processing event 1361 / 1386 [ETA: 0 s]
# Event 1361 not found
# Processing event 1362 / 1386 [ETA: 0 s]
# Event 1362 not found
# Processing event 1363 / 1386 [ETA: 0 s]
# Event 1363 not found
# Processing event 1364 / 1386 [ETA: 0 s]
# Event 1364 not found
# Processing event 1365 / 1386 [ETA: 0 s]
# Event 1365 not found
# Processing event 1366 / 1386 [ETA: 0 s]
# Event 1366 not found
# Processing event 1367 / 1386 [ETA: 0 s]
# Event 1367 not found
# Processing event 1368 / 1386 [ETA: 0 s]
# Event 1368 not found
# Processing event 1369 / 1386 [ETA: 0 s]
# Event 1369 not found
# Processing event 1370 / 1386 [ETA: 0 s]
# Event 1370 not found
# Processing event 1371 / 1386 [ETA: 0 s]
# Event 1371 not found
# Processing event 1372 / 1386 [ETA: 0 s]
# Event 1372 not found
# Processing event 1373 / 1386 [ETA: 0 s]
# Event 1373 not found
# Processing event 1374 / 1386 [ETA: 0 s]
# Event 1374 not found
# Processing event 1375 / 1386 [ETA: 0 s]
# Event 1375 not found
# Processing event 1376 / 1386 [ETA: 0 s]
# Event 1376 not found
# Processing event 1377 / 1386 [ETA: 0 s]
# Event 1377 not found
# Processing event 1378 / 1386 [ETA: 0 s]
# Event 1378 not found
# Processing event 1379 / 1386 [ETA: 0 s]
# Event 1379 not found
# Processing event 1380 / 1386 [ETA: 0 s]
# Event 1380 not found
# Processing event 1381 / 1386 [ETA: 0 s]
# Event 1381 not found
# Processing event 1382 / 1386 [ETA: 0 s]
# Event 1382 not found
# Processing event 1383 / 1386 [ETA: 0 s]
# Event 1383 not found
# Processing event 1384 / 1386 [ETA: 0 s]
# Event 1384 not found
# Processing event 1385 / 1386 [ETA: 0 s]
# Event 1385 not found
# Processing event 1386 / 1386 [ETA: 0 s]
# Event 1386 not found

# %% [markdown]
# Plot the waveforms of the event with the largest magnitude as a quick check:

# %%
event_id = catalogue_df["mag"].idxmax()
print(event_id, catalogue_df.loc[event_id])
event_data = np.load(os.path.join(processed_waveform_dir, "%d.npy" % event_id))
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(9, 9), sharex="all", sharey="all")

for i, trace in enumerate(event_data):
    for j in range(Ntrace):
        if np.abs(trace[:, j].sum() == 0):
            axes[j].plot(trace[:, j] + i * event_data.std(), c="r", lw=1)
        else:
            axes[j].plot(trace[:, j] + i * event_data.std(), c="k", lw=1)

plt.tight_layout()
plt.show()
# Out:
# 364 Unnamed: 0                                 364
# time          2010-07-07 23:53:34.280000+00:00
# lat                                    33.3809
# lon                                  -116.5054
# depth                                   7000.0
# mag                                        5.5
# Name: 364, dtype: object
# <img src="data:image/png;base64,..." width="900">
